# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection, metrics
import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense
warnings.filterwarnings("ignore")

# %%
class_names = data.class_names
print(class_names)
# Out:
# ['AD', 'CI', 'CN']

# %%
label_map = {0: 'CN', 1:'CI', 2: 'AD'}
print(label_map)
# Out:
# {0: 'CN', 1: 'CI', 2: 'AD'}

# %%
for images, labels in data:
    X = images.numpy().astype("uint8")
    y = labels.numpy().astype("uint8")
    y=2-y
    
print(X.shape, y.shape)
print (y)
# Out:
# (5154, 128, 128, 3) (5154,)
# [2 1 1 ... 1 1 0]

# %%
X_gray = np.zeros(shape = (*X.shape[:-1], 1))

for idx, img in enumerate(X):
    X_gray[idx] = tf.image.rgb_to_grayscale(img)

X = X_gray.copy()
print(X_gray.shape)
# Out:
# (5154, 128, 128, 1)

# %%
label_counts = pd.Series(y).value_counts()
print(label_counts)

# %%
visited = set()

for img, label in zip(X_gray, y):
    if len(visited) == 3:
        break
    if label in visited:
        continue
    visited.add(label)
    print(label_map[label])
    plt.gray()
    plt.imshow(img)
    plt.show()
# Out:
# CI
# AD
# CN

# %%
label_counts = pd.Series(y).value_counts()
print(label_counts)
# Out:
# 1    2590
# 0    1440
# 2    1124
# Name: count, dtype: int64

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip(mode = "horizontal_and_vertical"),
])

# %%
X_new, y_new = [], []
max_total = 3000
X_0, X_1, X_2 = X[y == 0], X[y == 1], X[y == 2]

for label, X_set in zip(label_map.keys(), [X_0, X_1, X_2]):
    count = 0
    for img in X_set:
        if count > max_total - label_counts[label]:
            break
        for i in range(2):
            augmented_img = data_augmentation(img)
            X_new.append(augmented_img)
            y_new.append(label)
            count += 1
        
X_new, y_new = np.array(X_new), np.array(y_new)
print(X_new.shape, y_new.shape)
# Out:
# (3852, 128, 128, 1) (3852,)

# %%
X = np.concatenate([X, X_new])
y = np.concatenate([y, y_new])

print(X.shape, y.shape)
# Out:
# (9006, 128, 128, 1) (9006,)

# %%
print(pd.Series(y).value_counts())
# Out:
# 2    3002
# 1    3002
# 0    3002
# Name: count, dtype: int64

# %%
#scaling
X = X / 255.0

print(X.min(), X.max())
# Out:
# 0.0 0.9921568627450981

# %%
# Splitting the data into training, testing and validation sets

X_train_val, X_test, y_train_val, y_test = model_selection.train_test_split(X, y, test_size = 0.20, 
                                                                            random_state = 3, stratify = y)

X_train, X_val, y_train, y_val = model_selection.train_test_split(X_train_val, y_train_val, test_size = 0.20, 
                                                                  random_state = 3, stratify = y_train_val)

print(X_train.shape, X_val.shape, X_test.shape)

print(f"Total instances: {X.shape[0]}\nTrain instances: {X_train.shape[0]}   \
        \nValidation instances: {X_val.shape[0]}\nTest instances: {X_test.shape[0]}")
# Out:
# (5763, 128, 128, 1) (1441, 128, 128, 1) (1802, 128, 128, 1)
# Total instances: 9006
# Train instances: 5763
# Validation instances: 1441
# Test instances: 1802

# %%
num_samples = X_train.shape[0]
X_train_reshaped = X_train.reshape(num_samples, -1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler()
X_sc_train = scaler.fit_transform(X_train_reshaped)

pca = PCA()#add n_components=the feature at 95%
pca.fit(X_sc_train)
features_pca_train = pca.fit_transform(X_sc_train)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')



plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()
xi = np.arange(1, 5764, step = 1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 15000, step = 1000)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)
ax.grid(axis='x')
plt.show()

# %%
n_components = 800
pca=PCA(n_components)
features_pca_train = pca.fit_transform(X_sc_train)
np.save('features_pca_train_normalized_NEWDATA.npy', features_pca_train)

# %%
# Model building
input=Input(shape=(800,))
x = Dense(units=200, activation="relu")(input)
x=Dense(units=100, activation="relu")(x)
x=Dense(units=50, activation="relu")(x)
x=Dense(units=3, activation="softmax")(x)

model=Model(inputs=input,outputs=x)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 200)            │       160,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 3)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 185,503 (724.62 KB)
#  Trainable params: 185,503 (724.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_arch = tf.keras.utils.plot_model(model, show_shapes = True)
model_arch
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# Model compilation
model.compile(optimizer = "adam", loss='sparse_categorical_crossentropy', metrics = ["accuracy"])

# %%
X_train.shape
# Out:
# (5763, 128, 128, 1)

# %%
y_train.shape
# Out:
# (5763,)

# %%
features_pca_train.shape
# Out:
# (5763, 800)

# %%
num_classes = 3
y_train_one_hot = tf.one_hot(y_train, depth=num_classes)

# %%
#cb1 = tf.keras.callbacks.ModelCheckpoint("clf_model.keras", save_best_only = True)
#cb2 = tf.keras.callbacks.EarlyStopping(patience = 5, restore_best_weights = True)

history = model.fit(features_pca_train, y_train, epochs = 5)
# Out:
# Epoch 1/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6709 - loss: 1.0438
# Epoch 2/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9944 - loss: 0.0332
# Epoch 3/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0053
# Epoch 4/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 5/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 6/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.9258e-04
# Epoch 7/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.8687e-04
# Epoch 8/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.7895e-04
# Epoch 9/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.8270e-04
# Epoch 10/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.2048e-04
# Epoch 11/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8336e-04
# Epoch 12/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.5267e-04
# Epoch 13/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.1941e-04
# Epoch 14/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.8515e-05
# Epoch 15/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.5337e-05
# Epoch 16/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.9758e-05
# Epoch 17/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.1792e-05
# Epoch 18/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.4695e-05
# Epoch 19/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.5946e-05
# Epoch 20/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.8373e-05
# Epoch 21/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.4300e-05
# Epoch 22/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.1930e-05
# Epoch 23/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.5459e-05
# Epoch 24/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.3384e-05
# Epoch 25/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.9480e-05
# Epoch 26/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.8150e-05
# Epoch 27/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.4450e-05
# Epoch 28/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3003e-05
# Epoch 29/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.1951e-05
# Epoch 30/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.1441e-05
# Epoch 31/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 9.5655e-06
# Epoch 32/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.2482e-06
# Epoch 33/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 7.4976e-06
# Epoch 34/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.0744e-06
# Epoch 35/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.0090e-06
# Epoch 36/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.0995e-06
# Epoch 37/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.8426e-06
# Epoch 38/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 4.0839e-06
# Epoch 39/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.7557e-06
# Epoch 40/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.3152e-06
# Epoch 41/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.8699e-06
# Epoch 42/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.7445e-06
# Epoch 43/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.3634e-06
# Epoch 44/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.3100e-06
# Epoch 45/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8710e-06
# Epoch 46/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.7208e-06
# Epoch 47/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5531e-06
# Epoch 48/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.4510e-06
# Epoch 49/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.3365e-06
# Epoch 50/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.0569e-06
# Epoch 51/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 9.8860e-07
# Epoch 52/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.4115e-07
# Epoch 53/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.2996e-07
# Epoch 54/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.5669e-07
# Epoch 55/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.6273e-07
# Epoch 56/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.7067e-07
# Epoch 57/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.3700e-07
# Epoch 58/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.8679e-07
# Epoch 59/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.6758e-07
# Epoch 60/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.7898e-07
# Epoch 61/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.4920e-07
# Epoch 62/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.1406e-07
# Epoch 63/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.7831e-07
# Epoch 64/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.5258e-07
# Epoch 65/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.3117e-07
# Epoch 66/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.0815e-07
# Epoch 67/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.7974e-07
# Epoch 68/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.6463e-07
# Epoch 69/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.4809e-07
# Epoch 70/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3576e-07
# Epoch 71/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1877e-07
# Epoch 72/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0736e-07
# Epoch 73/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.7728e-08
# Epoch 74/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.5225e-08
# Epoch 75/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.4850e-08
# Epoch 76/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.7367e-08
# Epoch 77/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.2588e-08
# Epoch 78/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.0683e-08
# Epoch 79/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.0666e-08
# Epoch 80/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.5965e-08
# Epoch 81/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.8791e-08
# Epoch 82/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.4665e-08
# Epoch 83/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.2312e-08
# Epoch 84/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.7202e-08
# Epoch 85/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.4980e-08
# Epoch 86/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.1695e-08
# Epoch 87/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.0061e-08
# Epoch 88/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.7483e-08
# Epoch 89/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.5510e-08
# Epoch 90/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.3730e-08
# Epoch 91/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.1439e-08
# Epoch 92/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0324e-08
# Epoch 93/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.7083e-09
# Epoch 94/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.2901e-09
# Epoch 95/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.2331e-09
# Epoch 96/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.9714e-09
# Epoch 97/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.4512e-09
# Epoch 98/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.1649e-09
# Epoch 99/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.0502e-09
# Epoch 100/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.3182e-09

# %%
# Confusion Matrix

y_train_pred = model.predict(X_train)
y_train_pred_labels = np.array([np.argmax(y_) for y_ in y_train_pred])

cm = tf.math.confusion_matrix(labels = y_train, predictions = y_train_pred_labels)
print(cm)
# Out:
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 30s 163ms/step
# tf.Tensor(
# [[1921    0    0]
#  [   0 1915    6]
#  [   0    0 1921]], shape=(3, 3), dtype=int32)

# %%
sns.heatmap(cm, annot = True)
plt.show()

# %%
tp_0, tn_0 = cm[0][0], cm[1][1] + cm[1][2] + cm[2][1] + cm[2][2]
fp_0, fn_0 = cm[1][0] + cm[2][0], cm[0][1] + cm[0][2]

tp_1, tn_1 = cm[1][1], cm[0][0] + cm[0][2] + cm[2][0] + cm[2][2]
fp_1, fn_1 = cm[0][1] + cm[2][1], cm[1][0] + cm[1][2]

tp_2, tn_2 = cm[2][2], cm[0][0] + cm[0][1] + cm[1][0] + cm[1][1]
fp_2, fn_2 = cm[0][2] + cm[1][2], cm[2][0] + cm[2][1]

def describeCM(tp, tn, fp, fn, i):
    print(f"\n\nClass {label_map[i]} : \n")
    print(f"True Positives : {tp}\nTrue Negatives : {tn}\nFalse Positives : {fp}\nFalse Negatives : {fn}")
    precision, recall = tp / (tp + fp), tp / (tp + fn)
    f1 = 2 * precision * recall / (precision + recall)
    print(f"\nPrecision : {precision}\nRecall (Sensitivity) : {recall}\nF1-Score : {f1}")
    
describeCM(tp_0, tn_0, fp_0, fn_0, 0)
describeCM(tp_1, tn_1, fp_1, fn_1, 1)
describeCM(tp_2, tn_2, fp_2, fn_2, 2)
# Out:
# Class AD :
#
# True Positives : 1921
# True Negatives : 3842
# False Positives : 0
# False Negatives : 0
#
# Precision : 1.0
# Recall (Sensitivity) : 1.0
# F1-Score : 1.0
#
#
# Class CI :
#
# True Positives : 1915
# True Negatives : 3842
# False Positives : 0
# False Negatives : 6
#
# Precision : 1.0
# Recall (Sensitivity) : 0.9968766267568975
# F1-Score : 0.9984358706986445
#
#
# Class CN :
#
# True Positives : 1921
# True Negatives : 3836
# False Positives : 6
# False Negatives : 0
#
# Precision : 0.9968863518422418
# Recall (Sensitivity) : 1.0
# F1-Score : 0.9984407484407484

# %%
# Classification Report

clf_report = metrics.classification_report(y_train, y_train_pred_labels)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1921
#            1       1.00      1.00      1.00      1921
#            2       1.00      1.00      1.00      1921
#
#     accuracy                           1.00      5763
#    macro avg       1.00      1.00      1.00      5763
# weighted avg       1.00      1.00      1.00      5763

# %% [markdown]
# ### Model Validation

# %%
num_classes = 3
y_test_one_hot = tf.one_hot(y_test, depth=num_classes)

# %%
# Evaluating the model on test set

loss, acc = model.evaluate(X_test, y_test_one_hot)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.9821 - loss: 0.0844

# %%
# Confusion Matrix

y_test_pred = model.predict(X_test)
y_test_pred_labels = np.array([np.argmax(y_) for y_ in y_test_pred])

cm = tf.math.confusion_matrix(labels = y_test, predictions = y_test_pred_labels)

sns.heatmap(cm, annot = True)
plt.show()
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step

# %%
tp_0, tn_0 = cm[0][0], cm[1][1] + cm[1][2] + cm[2][1] + cm[2][2]
fp_0, fn_0 = cm[1][0] + cm[2][0], cm[0][1] + cm[0][2]

tp_1, tn_1 = cm[1][1], cm[0][0] + cm[0][2] + cm[2][0] + cm[2][2]
fp_1, fn_1 = cm[0][1] + cm[2][1], cm[1][0] + cm[1][2]

tp_2, tn_2 = cm[2][2], cm[0][0] + cm[0][1] + cm[1][0] + cm[1][1]
fp_2, fn_2 = cm[0][2] + cm[1][2], cm[2][0] + cm[2][1]

def describeCM(tp, tn, fp, fn, i):
    print(f"\n\nClass {label_map[i]} : \n")
    print(f"True Positives : {tp}\nTrue Negatives : {tn}\nFalse Positives : {fp}\nFalse Negatives : {fn}")
    precision, recall = tp / (tp + fp), tp / (tp + fn)
    f1 = 2 * precision * recall / (precision + recall)
    print(f"\nPrecision : {precision}\nRecall (Sensitivity) : {recall}\nF1-Score : {f1}")
    
describeCM(tp_0, tn_0, fp_0, fn_0, 0)
describeCM(tp_1, tn_1, fp_1, fn_1, 1)
describeCM(tp_2, tn_2, fp_2, fn_2, 2)
# Out:
# Class AD :
#
# True Positives : 1921
# True Negatives : 3842
# False Positives : 0
# False Negatives : 0
#
# Precision : 1.0
# Recall (Sensitivity) : 1.0
# F1-Score : 1.0
#
#
# Class CI :
#
# True Positives : 1915
# True Negatives : 3842
# False Positives : 0
# False Negatives : 6
#
# Precision : 1.0
# Recall (Sensitivity) : 0.9968766267568975
# F1-Score : 0.9984358706986445
#
#
# Class CN :
#
# True Positives : 1921
# True Negatives : 3836
# False Positives : 6
# False Negatives : 0
#
# Precision : 0.9968863518422418
# Recall (Sensitivity) : 1.0
# F1-Score : 0.9984407484407484

# %%
# Classification Report

clf_report = metrics.classification_report(y_test, y_test_pred_labels)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       601
#            1       1.00      0.97      0.98       600
#            2       0.98      0.99      0.98       601
#
#     accuracy                           0.98      1802
#    macro avg       0.98      0.98      0.98      1802
# weighted avg       0.98      0.98      0.98      1802

# %% [markdown]
# ### Saving the Model

# %%
model.save("clf_model_final.h5")
